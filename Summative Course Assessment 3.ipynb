# %% [markdown]
# # Summative Course Assessment

# %% [markdown]
# **==========================================================================================================**

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datetime
from datetime import datetime, timedelta, date

# %matplotlib inline
#sets the default autosave frequency in seconds
# %autosave 60 
sns.set_style('dark')
sns.set(font_scale=1.2)
#sns.set(rc={'figure.figsize':(14,10)})

plt.rc('axes', titlesize=9)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format','{:.2f}'.format)

random.seed(0)
np.random.seed(0)
np.set_printoptions(suppress=True)
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# **==========================================================================================================**

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv("custinvoiceline.csv")
df
# Out:
#       CustomerId FirstName    LastName                                           Company                          Address                 City State Country PostalCode               Phone                 Fax                     Email  SupportRepId  InvoiceId InvoiceDate                   BillingAddress          BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0              1      Luís   Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3         98  2010-03-11  Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP         Brazil         12227-000   3.98            531     3247       1.99         1
# ...

# %%
# Write a SQL query that shows the total number of distinct tracks sold per invoice ordered by invoice date

# %%
df.sort_values(by="InvoiceDate")
# Out:
#       CustomerId FirstName    LastName Company                  Address       City State  Country PostalCode              Phone  Fax                      Email  SupportRepId  InvoiceId InvoiceDate           BillingAddress BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 38             2    Leonie      Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany      70174   +49 0711 2842222  NaN      leonekohler@surfeu.de             5          1  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany             70174   1.98              1        2       0.99         1
# ...

# %%
# Write a SQL query to find the number of distinct artists of the tracks sold in each invoice

# %%
df2 = pd.read_csv("invoicetrack.csv")
df2
# Out:
#       TrackId                                SongTitle  AlbumId  MediaTypeId  GenreId                                   Composer  Milliseconds      Bytes  UnitPrice_x                    Audiofile             Genre                                AlbumTitle  ArtistId                      ArtistName  InvoiceLineId  InvoiceId  UnitPrice_y  Quantity
# 0           1  For Those About To Rock (We Salute You)        1            1        1  Angus Young, Malcolm Young, Brian Johnson        343719   11170334         0.99              MPEG audio file              Rock     For Those About To Rock We Salute You         1                           AC/DC         579.00     108.00         0.99      1.00
# ...

# %%
df2.groupby("ArtistName", as_index=False)["InvoiceId"].count().sort_values(by="InvoiceId")
# Out:
#                                             ArtistName  InvoiceId
# 95                                        James Levine          0
# 192                                        Ton Koopman          0
# 74                                            Fretwork          0
# 112  London Symphony Orchestra & Sir Charles Mackerras          0
# 133                                      Nash Ensemble          0
# ..                                                 ...        ...
# 142                            Os Paralamas Do Sucesso         45
# 107                                       Led Zeppelin         87
# 125                                          Metallica         91
# 194                                                 U2        107
# 91                                         Iron Maiden        140
#
# [204 rows x 2 columns]

# %%
# Write a SQL query to list the number of distinct genres of tracks sold in each invoice. You may add WHERE conditions as needed to answer the following

# %%
invoice138 = df2[df2["InvoiceId"] == 138]
invoice138
# Out:
#       TrackId             SongTitle  AlbumId  MediaTypeId  GenreId                                           Composer  Milliseconds     Bytes  UnitPrice_x        Audiofile               Genre                                  AlbumTitle  ArtistId          ArtistName  InvoiceLineId  InvoiceId  UnitPrice_y  Quantity
# 362      1004          Over And Out       80            1        1  Dave Grohl, Taylor Hawkins, Nate Mendel, Chris...        316264  10428382         0.99  MPEG audio file                Rock                      In Your Honor [Disc 2]        84        Foo Fighters         744.00     138.00         0.99      1.00
# 369      1022     Hey, Johnny Park!       82            1        1                          Dave, Taylor, Nate, Chris        248528   8079480         0.99  MPEG audio file                Rock                    The Colour And The Shape        84        Foo Fighters         746.00     138.00         0.99      1.00
# ...

# %%
invoice138.Genre.value_counts()
# Out:
# Latin                 4
# Rock                  3
# Soundtrack            2
# Easy Listening        2
# Jazz                  1
# Metal                 1
# Alternative & Punk    1
# Name: Genre, dtype: int64

# %%
invoice40 = df2[df2["InvoiceId"] == 40]
invoice40
# Out:
#       TrackId                  SongTitle  AlbumId  MediaTypeId  GenreId                      Composer  Milliseconds     Bytes  UnitPrice_x        Audiofile        Genre                       AlbumTitle  ArtistId   ArtistName  InvoiceLineId  InvoiceId  UnitPrice_y  Quantity
# 394      1259            Fear Is The Key       99            1        1   Bruce Dickinson/Janick Gers        335307  13414528         0.99  MPEG audio file         Rock                 Fear Of The Dark        90  Iron Maiden         212.00      40.00         0.99      1.00
# 411      1313  Afraid To Shoot Strangers      103            1        1                           NaN        412525   9905048         0.99  MPEG audio file         Rock  Live At Donington 1992 (Disc 1)        90  Iron Maiden         218.00      40.00         0.99      1.00
# ...

# %%
invoice40.Genre.value_counts()
# Out:
# Metal          6
# Rock           4
# Heavy Metal    3
# Blues          1
# Name: Genre, dtype: int64

# %%
# Write a query to find the names of customers who have bought more than the average number of tracks, ordered by customer first name.

# %%
df3 = pd.read_csv("invoicecomb.csv")
df3
# Out:
#       InvoiceId  CustomerId InvoiceDate           BillingAddress BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0             1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany             70174   1.98              1        2       0.99         1
# 1             1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany             70174   1.98              2        4       0.99         1
# 2             2           4  2009-01-02         Ullevålsveien 14        Oslo          NaN         Norway              0171   3.96              3        6       0.99         1
# 3             2           4  2009-01-02         Ullevålsveien 14        Oslo          NaN         Norway              0171   3.96              4        8       0.99         1
# ...

# %%
df3.groupby("CustomerId")["TrackId"].count().mean()
# Out:
# 37.96610169491525

# %%
df3 = pd.read_csv("custinvoiceline.csv")
df3
# Out:
#       CustomerId FirstName    LastName                                           Company                          Address                 City State Country PostalCode               Phone                 Fax                     Email  SupportRepId  InvoiceId InvoiceDate                   BillingAddress          BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0              1      Luís   Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3         98  2010-03-11  Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP         Brazil         12227-000   3.98            531     3247       1.99         1
# ...

# %%
df3 = pd.read_csv("custinvoiceline.csv")
df3
# Out:
#       CustomerId FirstName    LastName                                           Company                          Address                 City State Country PostalCode               Phone                 Fax                     Email  SupportRepId  InvoiceId InvoiceDate                   BillingAddress          BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0              1      Luís   Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3         98  2010-03-11  Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP         Brazil         12227-000   3.98            531     3247       1.99         1
# ...

# %%
df3.groupby("CustomerId")["Quantity"].count().mean()
# Out:
# 37.96610169491525

# %%
#Write a query to find the name of the genres that have more tracks than the average number of tracks per genre. How many are there?

# %%
df4 = pd.read_csv("albumtrack.csv")
df4
# Out:
#       TrackId                                SongTitle  AlbumId  MediaTypeId  GenreId                                   Composer  Milliseconds      Bytes  UnitPrice                    Audiofile             Genre                                AlbumTitle  ArtistId                      ArtistName
# 0           1  For Those About To Rock (We Salute You)        1            1        1  Angus Young, Malcolm Young, Brian Johnson        343719   11170334       0.99              MPEG audio file              Rock     For Those About To Rock We Salute You         1                           AC/DC
# 1           6                    Put The Finger On You        1            1        1  Angus Young, Malcolm Young, Brian Johnson        205662    6713451       0.99              MPEG audio file              Rock     For Those About To Rock We Salute You         1                           AC/DC
# ...

# %%
trackmean = df4.groupby("Genre", as_index=False)["TrackId"].count()
trackmean
# Out:
#                  Genre  TrackId
# 0          Alternative       40
# 1   Alternative & Punk      332
# 2                Blues       81
# 3           Bossa Nova       15
# 4            Classical       74
# 5               Comedy       17
# 6                Drama       64
# 7       Easy Listening       24
# 8    Electronica/Dance       30
# 9          Heavy Metal       28
# 10         Hip Hop/Rap       35
# 11                Jazz      130
# 12               Latin      579
# 13               Metal      374
# 14               Opera        1
# 15                 Pop       48
# 16            R&B/Soul       61
# 17              Reggae       58
# 18                Rock     1297
# 19       Rock And Roll       12
# 20    Sci Fi & Fantasy       26
# 21     Science Fiction       13
# 22          Soundtrack       43
# 23            TV Shows       93
# 24               World       28

# %%
trackmean.mean()
# Out:
# TrackId   140.12
# dtype: float64

# %%
(trackmean.TrackId > 140).sum()
# Out:
# 4

# %%
trackmean.TrackId.max()
# Out:
# 1297

# %%
# How many customers have the same first name as their support representative?

# %%
employee = pd.read_csv("Employee.csv")
employee.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo            BirthDate             HireDate              Address      City State Country PostalCode              Phone                Fax                     Email
# 0           1    Adams    Andrew      General Manager        NaN  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1           2  Edwards     Nancy        Sales Manager       1.00  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2           3  Peacock      Jane  Sales Support Agent       2.00  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# ...

# %%
employee["FirstName"].value_counts()
# Out:
# Andrew      1
# Nancy       1
# Jane        1
# Margaret    1
# Steve       1
# Michael     1
# Robert      1
# Laura       1
# Name: FirstName, dtype: int64

# %%
customer = pd.read_csv("Customer.csv")
customer.head()
# Out:
#    CustomerId  FirstName     LastName                                           Company                          Address                 City State         Country PostalCode               Phone                 Fax                     Email  SupportRepId
# 0           1       Luís    Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3
# 1           2     Leonie       Köhler                                               NaN          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany      70174    +49 0711 2842222                 NaN     leonekohler@surfeu.de             5
# ...

# %%
customer["FirstName"].value_counts()
# Out:
# Frank        2
# Mark         2
# Luís         1
# João         1
# Madalena     1
# Hannah       1
# Fynn         1
# Niklas       1
# Camille      1
# Dominique    1
# Marc         1
# Wyatt        1
# Isabelle     1
# Terhi        1
# Ladislav     1
# Hugh         1
# Aaron        1
# Lucas        1
# Johannes     1
# Stanisław    1
# Enrique      1
# Joakim       1
# Emma         1
# Phil         1
# Steve        1
# Diego        1
# Luis         1
# Manoj        1
# Ellie        1
# Edward       1
# Martha       1
# Jennifer     1
# François     1
# Bjørn        1
# František    1
# Helena       1
# Astrid       1
# Daan         1
# Kara         1
# Eduardo      1
# Alexandre    1
# Roberto      1
# Fernanda     1
# Jack         1
# Leonie       1
# Michelle     1
# Tim          1
# Dan          1
# Kathy        1
# Heather      1
# John         1
# Victor       1
# Richard      1
# Patrick      1
# Julia        1
# Robert       1
# Puja         1
# ...

# %%
df5 = pd.read_csv("custinvoiceline.csv")
df5
# Out:
#       CustomerId FirstName    LastName                                           Company                          Address                 City State Country PostalCode               Phone                 Fax                     Email  SupportRepId  InvoiceId InvoiceDate                   BillingAddress          BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0              1      Luís   Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3         98  2010-03-11  Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP         Brazil         12227-000   3.98            531     3247       1.99         1
# ...

# %%
df6 = df5[df5["InvoiceDate"] >= "2013-12-01"]
df6.head()
# Out:
#      CustomerId FirstName LastName Company                Address     City State Country PostalCode              Phone  Fax                   Email  SupportRepId  InvoiceId InvoiceDate         BillingAddress BillingCity BillingState BillingCountry BillingPostalCode  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# 796          21     Kathy    Chase     NaN       801 W 4th Street     Reno    NV     USA      89503  +1 (775) 223-7665  NaN     kachase@hotmail.com             5        406  2013-12-04       801 W 4th Street        Reno           NV            USA             89503   1.98           2203     2946       0.99         1
# 797          21     Kathy    Chase     NaN       801 W 4th Street     Reno    NV     USA      89503  +1 (775) 223-7665  NaN     kachase@hotmail.com             5        406  2013-12-04       801 W 4th Street        Reno           NV            USA             89503   1.98           2204     2947       0.99         1
# ...

# %%
df6.groupby("Country").sum()
# Out:
#           CustomerId  SupportRepId  InvoiceId  Total  InvoiceLineId  TrackId  UnitPrice  Quantity
# Country
# Canada           174            18       2454  35.64          13281    17838       5.94         6
# Finland          616            42       5754 194.04          31255    43463      13.86        14
# India             58             3        412   1.99           2240     3177       1.99         1
# Portugal         315            36       3690  80.19          19989    27117       8.91         9
# USA              188            38       3258  23.76          17652    23617       7.92         8

# %%
df7 = pd.read_csv("Customer.csv")
df7.head()
# Out:
#    CustomerId  FirstName     LastName                                           Company                          Address                 City State         Country PostalCode               Phone                 Fax                     Email  SupportRepId
# 0           1       Luís    Gonçalves  Embraer - Empresa Brasileira de Aeronáutica S.A.  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566      luisg@embraer.com.br             3
# 1           2     Leonie       Köhler                                               NaN          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany      70174    +49 0711 2842222                 NaN     leonekohler@surfeu.de             5
# ...

# %%
df7["Email"].str.contains("yahoo").sum()
# Out:
# 18

# %% [markdown]
# **==========================================================================================================**

# %% [markdown]
# #### Python code done by Dennis Lam
